# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\Lenovo\Downloads\Practice+Questions+-+Session+2\Practice Questions - Session 2\Footwear_v2.csv")

# %%
df.head(2)
# Out:
#      Supplier  Delhi Mumbai Jaipur Hyderabad
# 0  Supplier 1  4.57%  4.18%  7.90%     8.54%
# 1  supplier 2  2.60%  1.88%  8.99%     9.23%

# %%
df['Delhi'] = df['Delhi'].str.replace( '%' , "")
df['Mumbai'] = df['Mumbai'].str.replace( '%' , "")
df['Jaipur'] = df['Jaipur'].str.replace( '%' , "")
df['Hyderabad'] = df['Hyderabad'].str.replace( '%' , "")

# %%
df.head(2)
# Out:
#      Supplier Delhi Mumbai Jaipur Hyderabad
# 0  Supplier 1  4.57   4.18   7.90      8.54
# 1  supplier 2  2.60   1.88   8.99      9.23

# %%
df.dtypes
# Out:
# Supplier     object
# Delhi        object
# Mumbai       object
# Jaipur       object
# Hyderabad    object
# dtype: object

# %%
df['Delhi'] = df['Delhi'].astype('float')
df['Mumbai'] = df['Mumbai'].astype('float')
df['Jaipur'] = df['Jaipur'].astype('float')
df['Hyderabad'] = df['Hyderabad'].astype('float')

# %%
df.dtypes
# Out:
# Supplier      object
# Delhi        float64
# Mumbai       float64
# Jaipur       float64
# Hyderabad    float64
# dtype: object

# %%
df['Delhi'].mean()
# Out:
# 6.323999999999999

# %%
df['Mumbai'].mean()
# Out:
# 4.555000000000001

# %%
6.323999999999999 - 4.555000000000001
# Out:
# 1.7689999999999984

# %%
data = [df['Delhi'],df['Mumbai'],df['Jaipur'],df['Hyderabad']]

# %%
plt.boxplot(x=(data))
plt.show()

# %%
cryp = pd.read_csv(r"C:\Users\Lenovo\Downloads\Practice+Questions+-+Session+2\Practice Questions - Session 2\crypto.csv")

# %%
cryp.head(2)
# Out:
#    Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# 0    7144.38    294.66      61.30      99.76      26.23     11.21
# 1    7022.76    298.89      55.17     102.92      26.32     10.44

# %%
cryp.dtypes
# Out:
# Close_btc    float64
# Close_et     float64
# Close_ltc    float64
# Close_mon    float64
# Close_neo    float64
# Close_qt     float64
# dtype: object

# %%
sns.pairplot(cryp[['Close_btc', 'Close_et', 'Close_ltc', 'Close_mon', 'Close_neo', 'Close_qt']],kind='reg')
plt.show()

# %%
df2 = cryp.corr()

# %%
df2.head(2)
# Out:
#            Close_btc  Close_et  Close_ltc  Close_mon  Close_neo  Close_qt
# Close_btc   1.000000  0.449322   0.657963   0.697058   0.734797  0.381921
# Close_et    0.449322  1.000000   0.490281   0.539489   0.481910  0.791373

# %%
sns.heatmap(df2)
# Out:
# <AxesSubplot:>
